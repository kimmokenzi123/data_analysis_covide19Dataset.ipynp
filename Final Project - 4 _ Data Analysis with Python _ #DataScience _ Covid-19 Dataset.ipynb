# %%
# working on real Project with python on 'COVID-19 Dataset'
# ( A part of Big Data Analysis)

# COVID-19 SMALL DATASET

# %%
# Dataset contains about 19000 rows.
#The data used here is till 29-april and has records as on 29-april-2020.
# This data is available as CSV file, 
#I will analyze this Data using Pandas DataFrame

# %%
import pandas as pd

# %%
data = pd.read_csv('covid_19_data.csv')

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
# Display the last few rows of the DataFrame
data.tail()
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263

# %%
# Display information about the DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
# Display descriptive statistics of the DataFrame
data.describe()
# Out:
#            Confirmed        Deaths      Recovered
# count     321.000000    321.000000     321.000000
# mean     9949.800623    709.152648    3030.277259
# std     31923.853086   3236.162817   14364.870365
# min         0.000000      0.000000       0.000000
# 25%       104.000000      2.000000       2.000000
# 50%       653.000000     12.000000      73.000000
# 75%      4655.000000    144.000000     587.000000
# max    299691.000000  27682.000000  132929.000000

# %%
# Display the column names of the DataFrame
data.columns
# Out:
# Index(['Date', 'State', 'Region', 'Confirmed', 'Deaths', 'Recovered'], dtype='object')

# %%
# Display the dimensions of the DataFrame (number of rows, number of columns)
data.shape
# Out:
# (321, 6)

# %%
# Display the index of the DataFrame
data.index
# Out:
# RangeIndex(start=0, stop=321, step=1)

# %%
# Display the data types of each column in the DataFrame
data.dtypes
# Out:
# Date         object
# State        object
# Region       object
# Confirmed     int64
# Deaths        int64
# Recovered     int64
# dtype: object

# %%
# Display the number of unique values in each column of the DataFrame
data.nunique
# Out:
# <bound method DataFrame.nunique of           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]>

# %%
# Data Cleaning
# Check for missing values and handle them appropriately:

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
# Handle missing values (if any)
# For example, we can fill missing values with the mean or median
data.fillna(data.mean(), inplace=True)
# Out:
# /var/folders/sz/95bttqcj5b348c7j20ptd9180000gn/T/ipykernel_861/4282275412.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.mean(), inplace=True)

# %%
# Data Analysis

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
#How does the number of confirmed cases, deaths, and recoveries evolve over time?

# %%
#  visualize the evolution of confirmed cases, deaths, and recoveries over time, we can create line plots. Here's an example code using the matplotlib library:

# %%
import matplotlib.pyplot as plt

# Assuming 'Date' is the column containing date information and is already in datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Sort the DataFrame by date
data = data.sort_values(by='Date')

# Plot the evolution of confirmed cases, deaths, and recoveries over time
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Confirmed'], label='Confirmed Cases', marker='o')
plt.plot(data['Date'], data['Deaths'], label='Deaths', marker='o')
plt.plot(data['Date'], data['Recovered'], label='Recovered', marker='o')

plt.title('COVID-19 Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend()
plt.grid(True)
plt.show()

# %%
#  noticeable trends or patterns in the data?

# %%
# Calculate and plot the moving averages for confirmed cases, deaths, and recoveries. This can help smooth out fluctuations and reveal underlying trends.

# %%
data.head(2)
# Out:
#           Date      State       Region  Confirmed  Deaths  Recovered
# 0   2020-04-29        NaN  Afghanistan       1939      60        252
# 217 2020-04-29  Greenland      Denmark         11       0         11

# %%
# Assuming 'Date' is the column containing date information and is already in datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Calculate 7-day moving averages
data['Confirmed_MA'] = data['Confirmed'].rolling(window=7).mean()
data['Deaths_MA'] = data['Deaths'].rolling(window=7).mean()
data['Recovered_MA'] = data['Recovered'].rolling(window=7).mean()

# Plot the moving averages
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Confirmed_MA'], label='Confirmed Cases (7-day MA)', marker='o')
plt.plot(data['Date'], data['Deaths_MA'], label='Deaths (7-day MA)', marker='o')
plt.plot(data['Date'], data['Recovered_MA'], label='Recovered (7-day MA)', marker='o')

plt.title('COVID-19 Cases Over Time (Moving Averages)')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Which regions  have the highest number of confirmed cases, deaths, and recoveries?

# %%
data.head(2)
# Out:
#           Date      State       Region  Confirmed  Deaths  Recovered  \
# 0   2020-04-29        NaN  Afghanistan       1939      60        252
# 217 2020-04-29  Greenland      Denmark         11       0         11
#
#      Confirmed_MA  Deaths_MA  Recovered_MA
# 0             NaN        NaN           NaN
# 217           NaN        NaN           NaN

# %%
# 'Region' is the column containing region information

# Total confirmed cases by region
total_confirmed = data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)

# %%
total_confirmed.head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
# Total deaths by region
total_deaths = data.groupby('Region')['Deaths'].sum().sort_values(ascending=False)

# %%
total_deaths.head(10)
# Out:
# Region
# US             60967
# Italy          27682
# UK             26166
# Spain          24275
# France         24121
# Belgium         7501
# Germany         6467
# Iran            5957
# Brazil          5513
# Netherlands     4727
# Name: Deaths, dtype: int64

# %%
# Total recoveries by region
total_recoveries = data.groupby('Region')['Recovered'].sum().sort_values(ascending=False)

# %%
total_recoveries.head(10)
# Out:
# Region
# Spain             132929
# US                120720
# Germany           120400
# Mainland China     77610
# Iran               73791
# Italy              71252
# France             49118
# Turkey             44040
# Brazil             34132
# Switzerland        22600
# Name: Recovered, dtype: int64

# %%
# Find the region with the highest number of confirmed cases
top_region_confirmed = data.loc[data['Confirmed'].idxmax(), 'Region']

# Find the total number of confirmed cases in that region
total_confirmed_top_region = data['Confirmed'].max()

# Display the result
print("Region with the Highest Number of Confirmed Cases:", top_region_confirmed)
print("Total Confirmed Cases in that Region:", total_confirmed_top_region)
# Out:
# Region with the Highest Number of Confirmed Cases: US
# Total Confirmed Cases in that Region: 299691

# %%
# Out:
# ('Total Confirmed Cases in that Region:', 299691)

# %%
# Out:
# Region with the Highest Number of Deaths: US
# Number of Deaths in the Top Region: 60967

# %%
# What is the overall mortality rate, calculated as the ratio of deaths to confirmed cases?

# %%
# Calculate the overall mortality rate
overall_mortality_rate = (data['Deaths'].sum() / data['Confirmed'].sum()) * 100

# Display the overall mortality rate
(f"Overall Mortality Rate: {overall_mortality_rate:.2f}%")
# Out:
# 'Overall Mortality Rate: 7.13%'

# %% [raw]
# #

# %%
data.head(2)
# Out:
#           Date      State       Region  Confirmed  Deaths  Recovered  \
# 0   2020-04-29        NaN  Afghanistan       1939      60        252
# 217 2020-04-29  Greenland      Denmark         11       0         11
#
#      Confirmed_MA  Deaths_MA  Recovered_MA
# 0             NaN        NaN           NaN
# 217           NaN        NaN           NaN

# %%
# 'Region' is the column containing region or state information

# Calculate mortality rate for each region
mortality_rate_by_region = (data.groupby('Region')['Deaths'].sum() / data.groupby('Region')['Confirmed'].sum()) * 100

# %%
mortality_rate_by_region.head(10)
# Out:
# Region
# Afghanistan             3.094379
# Albania                 3.916449
# Algeria                11.538462
# Andorra                 5.652759
# Angola                  7.407407
# Antigua and Barbuda    12.500000
# Argentina               4.994166
# Armenia                 1.552795
# Australia               1.347749
# Austria                 3.765745
# dtype: float64

# %%
# What is the overall recovery rate, calculated as the ratio of recoveries to confirmed cases?

# %%
# Calculate the overall recovery rate
overall_recovery_rate = (data['Recovered'].sum() / data['Confirmed'].sum()) * 100

# Display the overall recovery rate
(f"Overall Recovery Rate: {overall_recovery_rate:.2f}%")
# Out:
# 'Overall Recovery Rate: 30.46%'

# %%
# How does the recovery rate compare across different regions ?

# %%
# 'Region' is the column containing region information

# Calculate recovery rate for each region
recovery_rate_by_region = (data.groupby('Region')['Recovered'].sum() / data.groupby('Region')['Confirmed'].sum()) * 100

# %%
# Display the recovery rate for each region
recovery_rate_by_region
# Out:
# Region
# Afghanistan           12.996390
# Albania               59.399478
# Algeria               44.230769
# Andorra               56.931359
# Angola                25.925926
#                         ...
# West Bank and Gaza    20.639535
# Western Sahara        83.333333
# Yemen                 16.666667
# Zambia                55.670103
# Zimbabwe              15.625000
# Length: 187, dtype: float64

# %%
# In which region do we observe the highest and lowest numbers of cases, deaths, and recoveries?

# %%
# 'Region' is the column containing region information

# Region with the highest number of confirmed cases
highest_confirmed_region = data.groupby('Region')['Confirmed'].sum().idxmax()
highest_confirmed_cases = data.groupby('Region')['Confirmed'].sum().max()

# Region with the lowest number of confirmed cases
lowest_confirmed_region = data.groupby('Region')['Confirmed'].sum().idxmin()
lowest_confirmed_cases = data.groupby('Region')['Confirmed'].sum().min()

# Region with the highest number of deaths
highest_deaths_region = data.groupby('Region')['Deaths'].sum().idxmax()
highest_death_cases = data.groupby('Region')['Deaths'].sum().max()

# Region with the lowest number of deaths
lowest_deaths_region = data.groupby('Region')['Deaths'].sum().idxmin()
lowest_death_cases = data.groupby('Region')['Deaths'].sum().min()

# Region with the highest number of recoveries
highest_recoveries_region = data.groupby('Region')['Recovered'].sum().idxmax()
highest_recovery_cases = data.groupby('Region')['Recovered'].sum().max()

# Region with the lowest number of recoveries
lowest_recoveries_region = data.groupby('Region')['Recovered'].sum().idxmin()
lowest_recovery_cases = data.groupby('Region')['Recovered'].sum().min()

# Display the results
print("Region with the Highest Number of Confirmed Cases:", highest_confirmed_region, highest_confirmed_cases)
print("Region with the Lowest Number of Confirmed Cases:", lowest_confirmed_region, lowest_confirmed_cases)
print()
print("Region with the Highest Number of Deaths:", highest_deaths_region, highest_death_cases)
print("Region with the Lowest Number of Deaths:", lowest_deaths_region, lowest_death_cases)
print()
print("Region with the Highest Number of Recoveries:", highest_recoveries_region, highest_recovery_cases)
print("Region with the Lowest Number of Recoveries:", lowest_recoveries_region, lowest_recovery_cases)
# Out:
# Region with the Highest Number of Confirmed Cases: US 1039909
# Region with the Lowest Number of Confirmed Cases: Western Sahara 6
#
# Region with the Highest Number of Deaths: US 60967
# Region with the Lowest Number of Deaths: Bhutan 0
#
# Region with the Highest Number of Recoveries: Spain 132929
# Region with the Lowest Number of Recoveries: MS Zaandam 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#  'Region' is the column containing region information
# If you have 'State' as a separate column, replace 'Region' with 'State'

# Data preparation
data = {
    'Region': [highest_confirmed_region, lowest_confirmed_region, highest_deaths_region, lowest_deaths_region, highest_recoveries_region, lowest_recoveries_region],
    'Cases': [highest_confirmed_cases, lowest_confirmed_cases, highest_death_cases, lowest_death_cases, highest_recovery_cases, lowest_recovery_cases],
    'Type': ['Confirmed', 'Confirmed', 'Deaths', 'Deaths', 'Recoveries', 'Recoveries']
}

result_df = pd.DataFrame(data)

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x='Region', y='Cases', hue='Type', data=result_df)
plt.title('Highest and Lowest Numbers of Cases, Deaths, and Recoveries by Region')
plt.xlabel('Region')
plt.ylabel('Number of Cases')
plt.show()

# %%
# How do the daily changes in confirmed cases, deaths, and recoveries fluctuate?

# %%
import pandas as pd

# Assuming 'data' is your dictionary
data = {
    'Date': ['2020-01-01', '2020-01-02', '2020-01-03'],
    'Confirmed': [100, 150, 200],
    'Deaths': [5, 8, 10],
    'Recovered': [20, 30, 40]
}

# Convert the dictionary to a DataFrame
data = pd.DataFrame(data)

# Assuming 'Date' is not yet in datetime format, convert it
data['Date'] = pd.to_datetime(data['Date'])

# Sort the DataFrame by date
data = data.sort_values(by='Date')

# Calculate daily differences
data['DailyConfirmed'] = data['Confirmed'].diff()
data['DailyDeaths'] = data['Deaths'].diff()
data['DailyRecovered'] = data['Recovered'].diff()

# Display the DataFrame with daily changes
print(data[['Date', 'DailyConfirmed', 'DailyDeaths', 'DailyRecovered']])
# Out:
#         Date  DailyConfirmed  DailyDeaths  DailyRecovered
# 0 2020-01-01             NaN          NaN             NaN
# 1 2020-01-02            50.0          3.0            10.0
# 2 2020-01-03            50.0          2.0            10.0

# %%
# Assuming 'Date', 'Confirmed', 'Deaths', 'Recovered' are columns in your DataFrame
# Assuming 'Date' is already in datetime format

# Sort the DataFrame by date
data = data.sort_values(by='Date')

# Calculate daily differences
data['DailyConfirmed'] = data['Confirmed'].diff()
data['DailyDeaths'] = data['Deaths'].diff()
data['DailyRecovered'] = data['Recovered'].diff()

# Display the DataFrame with daily changes
print(data[['Date', 'DailyConfirmed', 'DailyDeaths', 'DailyRecovered']])
# Out:
#         Date  DailyConfirmed  DailyDeaths  DailyRecovered
# 0 2020-01-01             NaN          NaN             NaN
# 1 2020-01-02            50.0          3.0            10.0
# 2 2020-01-03            50.0          2.0            10.0

# %%
# Can you identify any spikes or sudden increases in the data?

# %%
# Set thresholds based on percentiles
threshold_confirmed = data['DailyConfirmed'].quantile(0.95)
threshold_deaths = data['DailyDeaths'].quantile(0.95)
threshold_recoveries = data['DailyRecovered'].quantile(0.95)

# %%
threshold_confirmed
# Out:
# 50.0

# %%
threshold_deaths
# Out:
# 2.95

# %%
threshold_recoveries
# Out:
# 10.0

# %%
data.head(2)
# Out:
#         Date  Confirmed  Deaths  Recovered  DailyConfirmed  DailyDeaths  \
# 0 2020-01-01        100       5         20             NaN          NaN
# 1 2020-01-02        150       8         30            50.0          3.0
#
#    DailyRecovered
# 0             NaN
# 1            10.0

# %%
#  Remove all the records where confirmed is less than 10.

# %%
#  'Confirmed' is the column in your DataFrame
data_filtered = data[data['Confirmed'] >= 10]

# %%
data_filtered
# Out:
#         Date  Confirmed  Deaths  Recovered  DailyConfirmed  DailyDeaths  \
# 0 2020-01-01        100       5         20             NaN          NaN
# 1 2020-01-02        150       8         30            50.0          3.0
# 2 2020-01-03        200      10         40            50.0          2.0
#
#    DailyRecovered
# 0             NaN
# 1            10.0
# 2            10.0

# %%
# How many Confirmed , Deaths & Recovered cases were reported from Canada till 29 april 2020?

# %%
# Print the column names in your DataFrame
data.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'DailyConfirmed',
#        'DailyDeaths', 'DailyRecovered'],
#       dtype='object')

# %%
## Print general information about the DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            3 non-null      datetime64[ns]
#  1   Confirmed       3 non-null      int64
#  2   Deaths          3 non-null      int64
#  3   Recovered       3 non-null      int64
#  4   DailyConfirmed  2 non-null      float64
#  5   DailyDeaths     2 non-null      float64
#  6   DailyRecovered  2 non-null      float64
# dtypes: datetime64[ns](1), float64(3), int64(3)
# memory usage: 192.0 bytes

# %%
# Print the first few rows of the DataFrame
data.head()
# Out:
#         Date  Confirmed  Deaths  Recovered  DailyConfirmed  DailyDeaths  \
# 0 2020-01-01        100       5         20             NaN          NaN
# 1 2020-01-02        150       8         30            50.0          3.0
# 2 2020-01-03        200      10         40            50.0          2.0
#
#    DailyRecovered
# 0             NaN
# 1            10.0
# 2            10.0

# %%
data = pd.read_csv('covid_19_data.csv')

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
# Assuming 'Region' is the column containing country information and 'State' for states
canada_states_data = data[(data['Region'] == 'Canada') & (data['Date'] <= '2020-04-29')]

# %%
canada_states_data
# Out:
# Empty DataFrame
# Columns: [Date, State, Region, Confirmed, Deaths, Recovered]
# Index: []

# %%
# Out:
#           Date                         State  Region  Confirmed  Deaths  \
# 183  4/29/2020                       Alberta  Canada       5165      87
# 193  4/29/2020              British Columbia  Canada       2087     109
# 203  4/29/2020  Diamond Princess cruise ship  Canada          0       1
# 215  4/29/2020                Grand Princess  Canada         13       0
# 246  4/29/2020                      Manitoba  Canada        275       6
# 259  4/29/2020                 New Brunswick  Canada        118       0
# 266  4/29/2020     Newfoundland and Labrador  Canada        258       3
# 272  4/29/2020         Northwest Territories  Canada          5       0
# 273  4/29/2020                   Nova Scotia  Canada        935      28
# 276  4/29/2020                       Ontario  Canada      16978    1153
# 279  4/29/2020          Prince Edward Island  Canada         27       0
# 282  4/29/2020                        Quebec  Canada      26610    1762
# ...

# %%
# How many Confirmed , Deaths & Recovered cases were reported from US by State

# %%
data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
# Assuming 'Region' is the column containing country information and 'State' for states
us_data = data[data['Region'] == 'US']

# %%
us_data
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'Region' is the column containing country information and 'State' for states
us_data = data[data['Region'] == 'US']

# Group by 'State' and calculate total confirmed, deaths, and recovered cases for each state
us_data_by_state = us_data.groupby('State').agg({
    'Confirmed': 'sum',
    'Deaths': 'sum',
    'Recovered': 'sum'
}).reset_index()

# Plotting a bar chart for confirmed, deaths, and recovered cases by state
us_data_by_state.plot(x='State', kind='bar', stacked=True, figsize=(12, 8))
plt.title('Confirmed, Deaths, and Recovered Cases in the United States by State')
plt.xlabel('State')
plt.ylabel('Count')
plt.show()

# %%
# Sort the entire data wrt No of Recovered cases in descending order.

# %%
# Assuming you have a DataFrame named 'data'
sorted_data_by_recovered = data.sort_values(by='Recovered', ascending=False)

# %%
sorted_data_by_recovered
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]
